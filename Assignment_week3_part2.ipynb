# %% [markdown]
# # Part 1

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import requests # library to handle requests

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
#import geocoder # import geocoder

from bs4 import BeautifulSoup # library to parse HTML and XML documents

print('Libraries imported.')

# %matplotlib inline
# Out:
# Libraries imported.

# %%
URL = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
toronto = requests.get(URL)
toronto_df = pd.read_html(toronto.content, header = 0)[0]

# %%
toronto_df.head()
# Out:
#   Postal Code           Borough              Neighbourhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
neighborhoods_df = toronto_df.copy()
neighborhoods_df.describe()
# Out:
#        Postal Code       Borough Neighbourhood
# count          180           180           180
# unique         180            11           100
# top            M7R  Not assigned  Not assigned
# freq             1            77            77

# %%
neighborhoods_df = neighborhoods_df[neighborhoods_df.Borough != 'Not assigned']
neighborhoods_df.describe()
# Out:
#        Postal Code     Borough Neighbourhood
# count          103         103           103
# unique         103          10            99
# top            M5L  North York     Downsview
# freq             1          24             4

# %%
neighborhoods_df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
len(neighborhoods_df['Postal Code'].unique())
# Out:
# 103

# %% [markdown]
# ==> Already more than one neighborhood can exist in one postal code area.

# %%
neighborhoods_df[neighborhoods_df.Borough == 'Not assigned']
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighbourhood]
# Index: []

# %% [markdown]
# ==> There is not 'Not assigned' in neighborhood.

# %%
neighborhoods_df.shape
# Out:
# (103, 3)

# %% [markdown]
# # Part 2

# %%
codetable_df = pd.read_csv("Geospatial_Coordinates.csv")
codetable_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
neighborhoods_Latitude = []
neighborhoods_Longitude = []

for i in range(len(neighborhoods_df)):
    temp_code = neighborhoods_df.iloc[i]['Postal Code']
    
    neighborhoods_Latitude.append(codetable_df[codetable_df['Postal Code']== temp_code].iloc[0][1])
    neighborhoods_Longitude.append(codetable_df[codetable_df['Postal Code']== temp_code].iloc[0][2])

# %%
len(neighborhoods_Latitue)
# Out:
# 103

# %%
neighborhoods_df = neighborhoods_df.assign(Latitude=neighborhoods_Latitude, Logitude=neighborhoods_Longitude)

# %%
neighborhoods_df
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# 8           M9A         Etobicoke
# 9           M1B       Scarborough
# 11          M3B        North York
# 12          M4B         East York
# 13          M5B  Downtown Toronto
# 14          M6B        North York
# 17          M9B         Etobicoke
# 18          M1C       Scarborough
# 20          M3C        North York
# 21          M4C         East York
# 22          M5C  Downtown Toronto
# 23          M6C              York
# 26          M9C         Etobicoke
# 27          M1E       Scarborough
# 30          M4E      East Toronto
# 31          M5E  Downtown Toronto
# 32          M6E              York
# 36          M1G       Scarborough
# 39          M4G         East York
# 40          M5G  Downtown Toronto
# 41          M6G  Downtown Toronto
# ...
